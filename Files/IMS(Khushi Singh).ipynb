# %%
record = { 
           101 : {"product name" : "Algina Tablets" , "product category" : "Paracetamol" , "MFG Date" : "22-06-2021" , "Price" : 7.00 , "Expirey Date" : "22-12-2021" ,"Power" : "500mg","Quantity" : 1000},
           102 : {"product name" : "Cipmol Tablets" , "product category" : "Paracetamol" , "MFG Date" : "22-06-2021" , "Price" : 9 , "Expirey Date" : "22-12-2021" ,"Power" : "500mg","Quantity" : 4000},
           103 : {"product name" : "Malidens Tablets" , "product category" : "Paracetamol" , "MFG Date" : "22-06-2021" , "Price" : 10 , "Expirey Date" : "22-12-2021" ,"Power" : "500mg","Quantity" : 3000},
           104 : {"product name" : "Parafast Tablets" , "product category" : "Paracetamol" , "MFG Date" : "22-06-2021" , "Price" : 10 , "Expirey Date" : "22-12-2021" ,"Power" : "500mg","Quantity" : 1000},
           105 : {"product name" : "Paracip Tablets" , "product category" : "Paracetamol" , "MFG Date" : "22-06-2021" , "Price" : 11 , "Expirey Date" : "22-12-2021" ,"Power" : "500mg","Quantity" : 6000},
           106 : {"product name" : "Doliza Tablets" , "product category" : "Paracetamol" , "MFG Date" : "22-06-2021" , "Price" : 11 , "Expirey Date" : "22-12-2021" ,"Power" : "500mg","Quantity" : 3000},
           107 : {"product name" : "Cipflam Tablets" , "product category" : "Paracetamol" , "MFG Date" : "22-06-2021" , "Price" : 12 , "Expirey Date" : "22-12-2021" ,"Power" : "500mg","Quantity" : 1500},
           108 : {"product name" : "Fepanil Tablets" , "product category" : "Paracetamol" , "MFG Date" : "22-06-2021" , "Price" : 13 , "Expirey Date" : "22-12-2021" ,"Power" : "500mg","Quantity" : 2000},
           109 : {"product name" : "Dolo Tablets" , "product category" : "Paracetamol" , "MFG Date" : "22-06-2021" , "Price" : 14 , "Expirey Date" : "22-12-2021" ,"Power" : "500mg","Quantity" : 1800},
           110 : {"product name" : "Pacimol Tablets" , "product category" : "Paracetamol" , "MFG Date" : "22-06-2021" , "Price" : 15 , "Expirey Date" : "22-12-2021" ,"Power" : "500mg","Quantity" : 1000},
           111 : {"product name" : "Crocin Advance Tablets" , "product category" : "Paracetamol" , "MFG Date" : "22-06-2021" , "Price" : 16 , "Expirey Date" : "22-12-2021" ,"Power" : "500mg","Quantity" : 2800},
           112 : {"product name" : "Calpol Tablets" , "product category" : "Paracetamol" , "MFG Date" : "22-06-2021" , "Price" : 17 , "Expirey Date" : "22-12-2021" ,"Power" : "500mg","Quantity" : 2600},
           113 : {"product name" : "Pacimol XP Tablets" , "product category" : "Paracetamol" , "MFG Date" : "22-06-2021" , "Price" : 18 , "Expirey Date" : "22-12-2021" ,"Power" : "500mg","Quantity" : 1100},
           114 : {"product name" : "C 37 Tablets" , "product category" : "Paracetamol" , "MFG Date" : "22-06-2021" , "Price" : 23 , "Expirey Date" : "22-12-2021" ,"Power" : "500mg","Quantity" : 1200},
           115 : {"product name" : "Crocin Tablets" , "product category" : "Paracetamol" , "MFG Date" : "22-06-2021" , "Price" : 30 , "Expirey Date" : "22-12-2021" ,"Power" : "500mg","Quantity" : 3800}, 
           116 : {"product name" : "Actiflu Tablets" , "product category" : "Paracetamol" , "MFG Date" : "22-06-2021" , "Price" : 38 , "Expirey Date" : "22-12-2021" ,"Power" : "500mg","Quantity" : 1000},
           117 : {"product name" : "Perfalgan Tablets" , "product category" : "Paracetamol" , "MFG Date" : "22-06-2021" , "Price" : 165 , "Expirey Date" : "22-12-2021" ,"Power" : "500mg","Quantity" : 1500},
           118 : {"product name" : "Amoxicillin Tablets" , "product category" : "Cough & Cold" , "MFG Date" : "22-06-2021" , "Price" : 10 , "Expirey Date" : "22-12-2021" ,"Power" : "300mg","Quantity" : 1800},
           119 : {"product name" : "Doxycycline Tablets" , "product category" : "Cough & Cold" , "MFG Date" : "22-06-2021" , "Price" : 13 , "Expirey Date" : "22-12-2021" ,"Power" : "500mg","Quantity" : 4000},
           120 : {"product name" : "Cephalexin Tablets" , "product category" : "Cough & Cold" , "MFG Date" : "22-06-2021" , "Price" : 12 , "Expirey Date" : "22-12-2021" ,"Power" : "50mg","Quantity" : 5000},
           121 : {"product name" : "Ciprofloacin Tablets" , "product category" : "Cough & Cold" , "MFG Date" : "22-06-2021" , "Price" : 10 , "Expirey Date" : "22-12-2021" ,"Weight" : "100mg","Quantity" : 1000},
           122 : {"product name" : "ClindamycinTablets" , "product category" : "Cough & Cold" , "MFG Date" : "22-06-2021" , "Price" : 13 , "Expirey Date" : "22-12-2021" ,"Weight" : "500mg","Quantity" : 5000},
           123 : {"product name" : "Metronidazole Tablets" , "product category" : "Cough & Cold" , "MFG Date" : "22-06-2021" , "Price" : 19 , "Expirey Date" : "22-12-2021" ,"Weight" : "50mg","Quantity" :3000},
           124 : {"product name" : "Azithromycin Tablets" , "product category" : "Cough & Cold" , "MFG Date" : "22-06-2021" , "Price" : 100 , "Expirey Date" : "22-12-2021" ,"Weight" : "500mg","Quantity" : 2000},
           125 : {"product name" : "Gluconorm-G Tablets" , "product category" : "Diabetes" , "MFG Date" : "22-06-2021" , "Price" : 30 , "Expirey Date" : "22-12-2021" ,"Weight" : "200mg","Quantity" : 2000},
           126 : {"product name" : "Novomix Tablets" , "product category" : "Diabetes" , "MFG Date" : "22-06-2021" , "Price" : 20 , "Expirey Date" : "22-12-2021" ,"Weight" : "500mg","Quantity" : 2000},
           127 : {"product name" : "Mixtard Tablets" , "product category" : "Diabetes" , "MFG Date" : "22-06-2021" , "Price" : 50 , "Expirey Date" : "22-12-2021" ,"Weight" : "500mg","Quantity" : 2000},
           128 : {"product name" : "Lantus Tablets" , "product category" : "Diabetes" , "MFG Date" : "22-06-2021" , "Price" : 130 , "Expirey Date" : "22-12-2021" ,"Weight" : "500mg","Quantity" : 2000},
           129 : {"product name" : "Thyroid Desiccated Tablets" , "product category" : "Thyroid" , "MFG Date" : "22-06-2021" , "Price" : 110 , "Expirey Date" : "22-12-2021" ,"Weight" : "500mg","Quantity" :1000 },
           130 : {"product name" : "Levothyroxine Tablets" , "product category" : "Thyroid" , "MFG Date" : "22-06-2021" , "Price" : 200 , "Expirey Date" : "22-12-2021" ,"Weight" : "500mg","Quantity" :1000 },
           131 : {"product name" : "Liotrix Tablets" , "product category" : "Thyroid" , "MFG Date" : "22-06-2021" , "Price" : 100 , "Expirey Date" : "22-12-2021" ,"Weight" : "500mg","Quantity" : 1000},
          }

# %%
import json

# %%
js = json.dumps(record)

# %%
js
# Out:
# '{"101": {"product name": "Algina Tablets", "product category": "Paracetamol", "MFG Date": "22-06-2021", "Price": 7.0, "Expirey Date": "22-12-2021", "Power": "500mg", "Quantity": 1000}, "102": {"product name": "Cipmol Tablets", "product category": "Paracetamol", "MFG Date": "22-06-2021", "Price": 9, "Expirey Date": "22-12-2021", "Power": "500mg", "Quantity": 4000}, "103": {"product name": "Malidens Tablets", "product category": "Paracetamol", "MFG Date": "22-06-2021", "Price": 10, "Expirey Date": "22-12-2021", "Power": "500mg", "Quantity": 3000}, "104": {"product name": "Parafast Tablets", "product category": "Paracetamol", "MFG Date": "22-06-2021", "Price": 10, "Expirey Date": "22-12-2021", "Power": "500mg", "Quantity": 1000}, "105": {"product name": "Paracip Tablets", "product category": "Paracetamol", "MFG Date": "22-06-2021", "Price": 11, "Expirey Date": "22-12-2021", "Power": "500mg", "Quantity": 6000}, "106": {"product name": "Doliza Tablets", "product category": "Paracetamol", "MFG Date": "22-06-2021", "Price": 11, "Expirey Date": "22-12-2021", "Power": "500mg", "Quantity": 3000}, "107": {"product name": "Cipflam Tablets", "product category": "Paracetamol", "MFG Date": "22-06-2021", "Price": 12, "Expirey Date": "22-12-2021", "Power": "500mg", "Quantity": 1500}, "108": {"product name": "Fepanil Tablets", "product category": "Paracetamol", "MFG Date": "22-06-2021", "Price": 13, "Expirey Date": "22-12-2021", "Power": "500mg", "Quantity": 2000}, "109": {"product name": "Dolo Tablets", "product category": "Paracetamol", "MFG Date": "22-06-2021", "Price": 14, "Expirey Date": "22-12-2021", "Power": "500mg", "Quantity": 1800}, "110": {"product name": "Pacimol Tablets", "product category": "Paracetamol", "MFG Date": "22-06-2021", "Price": 15, "Expirey Date": "22-12-2021", "Power": "500mg", "Quantity": 1000}, "111": {"product name": "Crocin Advance Tablets", "product category": "Paracetamol", "MFG Date": "22-06-2021", "Price": 16, "Expirey Date": "22-12-2021", "Power": "500mg", "Quantity": 2800}, "112": {"product name": "Calpol Tablets", "product category": "Paracetamol", "MFG Date": "22-06-2021", "Price": 17, "Expirey Date": "22-12-2021", "Power": "500mg", "Quantity": 2600}, "113": {"product name": "Pacimol XP Tablets", "product category": "Paracetamol", "MFG Date": "22-06-2021", "Price": 18, "Expirey Date": "22-12-2021", "Power": "500mg", "Quantity": 1100}, "114": {"product name": "C 37 Tablets", "product category": "Paracetamol", "MFG Date": "22-06-2021", "Price": 23, "Expirey Date": "22-12-2021", "Power": "500mg", "Quantity": 1200}, "115": {"product name": "Crocin Tablets", "product category": "Paracetamol", "MFG Date": "22-06-2021", "Price": 30, "Expirey Date": "22-12-2021", "Power": "500mg", "Quantity": 3800}, "116": {"product name": "Actiflu Tablets", "product category": "Paracetamol", "MFG Date": "22-06-2021", "Price": 38, "Expirey Date": "22-12-2021", "Power": "500mg", "Quantity": 1000}, "117": {"product name": "Perfalgan Tablets", "product category": "Paracetamol", "MFG Date": "22-06-2021", "Price": 165, "Expirey Date": "22-12-2021", "Power": "500mg", "Quantity": 1500}, "118": {"product name": "Amoxicillin Tablets", "product category": "Cough & Cold", "MFG Date": "22-06-2021", "Price": 10, "Expirey Date": "22-12-2021", "Power": "300mg", "Quantity": 1800}, "119": {"product name": "Doxycycline Tablets", "product category": "Cough & Cold", "MFG Date": "22-06-2021", "Price": 13, "Expirey Date": "22-12-2021", "Power": "500mg", "Quantity": 4000}, "120": {"product name": "Cephalexin Tablets", "product category": "Cough & Cold", "MFG Date": "22-06-2021", "Price": 12, "Expirey Date": "22-12-2021", "Power": "50mg", "Quantity": 5000}, "121": {"product name": "Ciprofloacin Tablets", "product category": "Cough & Cold", "MFG Date": "22-06-2021", "Price": 10, "Expirey Date": "22-12-2021", "Weight": "100mg", "Quantity": 1000}, "122": {"product name": "ClindamycinTablets", "product category": "Cough & Cold", "MFG Date": "22-06-2021", "P ...

# %%
fd = open("record.json",'w')

fd.write(js)

fd.close()

# %%
fd = open("record.json",'r')
txt = fd.read()
fd.close()

# %%
record = json.loads(txt)

# %%
record
# Out:
# {'101': {'product name': 'Algina Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 7.0,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 1000},
#  '102': {'product name': 'Cipmol Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 9,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 4000},
#  '103': {'product name': 'Malidens Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 10,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 3000},
#  '104': {'product name': 'Parafast Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 10,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 1000},
#  '105': {'product name': 'Paracip Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 11,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 6000},
#  '106': {'product name': 'Doliza Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 11,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 3000},
#  '107': {'product name': 'Cipflam Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 12,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 1500},
#  '108': {'product name': 'Fepanil Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 13,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 2000},
#  '109': {'product name': 'Dolo Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 14,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 1800},
#  '110': {'product name': 'Pacimol Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 15,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 1000},
#  '111': {'product name': 'Crocin Advance Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 16,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 2800},
#  '112': {'product name': 'Calpol Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 17,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 2600},
#  '113': {'product name': 'Pacimol XP Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 18,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 1100},
#  '114': {'product name': 'C 37 Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 23,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 1200},
#  '115': {'product name': 'Crocin Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 30,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 3800},
#  '116': {'product name': 'Actiflu Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 38,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 1000},
#  '117': {'product name': 'Perfalgan Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 165,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 1500},
#  '118': {'product name': 'Amoxicillin Tablets',
#   'product category': 'Cough & Cold',
#   'MFG Date': '22-06-2021',
#   'Price': 10,
#   'Expirey Date': '22-12-2021',
#   'Power': '300mg',
#   'Quantity': 1800},
#  '119': {'product name': 'Doxycycline Tablets',
#   'product category': 'Cough & Cold',
#   'MFG Date': '22-06-2021',
#   'Price': 13,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 4000},
#  '120': {'product name': 'Cephalexin Tablets',
#   'product category': 'Cough & Cold',
#   'MFG Date': '22-06-2021',
#   'Price': 12,
#   'Expirey Date': '22-12-2021',
#   'Power': '50mg',
#   'Quantity': 5000},
#  '121': {'product name': 'Ciprofloacin Tablets',
#   'product category': 'Cough & Cold',
#   'MFG Date': '22-06-2021',
#   'Price': 10,
#   'Expirey Date': '22-12-2021',
#   'Weight': '100mg',
#   'Quantity': 1000},
#  '122': {'product name': 'ClindamycinTablets',
#   'product category': 'Cough & Cold',
#   'MFG Date': '22-06-2021',
#   'Price': 13,
#   'Expirey Date': '22-12-2021',
#   'Weight': '500mg',
#   'Quantity': 5000},
#  '123': {'product name': 'Metronidazole Tablets',
#   'product category': 'Cough & Cold',
#   'MFG Date': '22-06-2021',
#   'Price': 19,
#   'Expirey Date': '22-12-2021',
#   'Weight': '50mg',
#   'Quantity': 3000},
#  '124': {'product name': 'Azithromycin Tablets',
#   'product category': 'Cough & Cold',
#   'MFG Date': '22-06-2021',
#   'Price': 100,
#   'Expirey Date': '22-12-2021',
#   'Weight': '500mg',
#   'Quantity': 2000},
#  '125': {'product name': 'Gluconorm-G Tablets',
#   'product category': 'Diabetes',
#   'MFG Date': '22-06-2021',
#   'Price': 30,
#   'Expirey Date': '22-12-2021',
#   'Weight': '200mg',
#   'Quantity': 2000},
#  '126': {'product name': 'Novomix Tablets',
#   'product category': 'Diabetes',
#   'MFG Date': '22-06-2021',
#   'Price': 20,
#   'Expirey Date': '22-12-2021',
#   'Weight': '500mg',
#   'Quantity': 2000},
#  '127': {'product name': 'Mixtard Tablets',
#   'product category': 'Diabetes',
#   'MFG Date': '22-06-2021',
#   'Price': 50,
#   'Expirey Date': '22-12-2021',
#   'Weight': '500mg',
#   'Quantity': 2000},
#  '128': {'product name': 'Lantus Tablets',
#   'product category': 'Diabetes',
#   'MFG Date': '22-06-2021',
#   'Price': 130,
#   'Expirey Date': '22-12-2021',
#   'Weight': '500mg',
#   'Quantity': 2000},
#  '129': {'product name': 'Thyroid Desiccated Tablets',
#   'product category': 'Thyroid',
#   'MFG Date': '22-06-2021',
#   'Price': 110,
#   'Expirey Date': '22-12-2021',
#   'Weight': '500mg',
#   'Quantity': 1000},
#  '130': {'product name': 'Levothyroxine Tablets',
#   'product category': 'Thyroid',
#   'MFG Date': '22-06-2021',
#   'Price': 200,
#   'Expirey Date': '22-12-2021',
#   'Weight': '500mg',
#   'Quantity': 1000},
#  '131': {'product name': 'Liotrix Tablets',
#   'product category': 'Thyroid',
#   'MFG Date': '22-06-2021',
#   'Price': 100,
#   'Expirey Date': '22-12-2021',
#   'Weight': '500mg',
#   'Quantity': 1000}}

# %%
# From here our inventory management system application will start

# %%
name = input("Dear Customer!! Enter your name: ".title())
try:
  Contact_Number = int(input("Enter your contact number: ".title()))
except Exception as e:
    e = "Enter a valid number"
    print(e) 
    Contact_Number = int(input("Enter your contact number: ".title()))  
    
print("\nWelcome " + name + " here is the list of the products we have in our store: \n")
for products in record:
  print(products , "Product ID:")
  print("Product Name: " , record[products]['product name'])
  print("Product Category: " ,record[products]['product category'])
  print("Product Weight: " ,record[products]['Power'])
  print("Product Price: " ,record[products]['Price'])
  print("Product Manufacturing Date: " ,record[products]['MFG Date'])
  print("Product Expiery Date: " ,record[products]['Expirey Date'])
  print("Product Quantity In Inventory: " , record[products]['Quantity'])
  print("******************************\n")
# Out:
# Dear Customer!! Enter Your Name: khushi
# Enter Your Contact Number: jjdakd
# Enter a valid number
# Enter Your Contact Number: 2882772829
#
# Welcome khushi  here is the list of the products we have in our store:
#
# 101 Product ID:
# Product Name:  Algina Tablets
# Product Category:  Paracetamol
# Product Weight:  500mg
# Product Price:  7.0
# Product Manufacturing Date:  22-06-2021
# Product Expiery Date:  22-12-2021
# Product Quantity In Inventory:  1000
# ******************************
#
# 102 Product ID:
# Product Name:  Cipmol Tablets
# Product Category:  Paracetamol
# Product Weight:  500mg
# Product Price:  9
# Product Manufacturing Date:  22-06-2021
# Product Expiery Date:  22-12-2021
# Product Quantity In Inventory:  4000
# ******************************
#
# 103 Product ID:
# Product Name:  Malidens Tablets
# Product Category:  Paracetamol
# Product Weight:  500mg
# Product Price:  10
# Product Manufacturing Date:  22-06-2021
# Product Expiery Date:  22-12-2021
# Product Quantity In Inventory:  3000
# ******************************
#
# 104 Product ID:
# Product Name:  Parafast Tablets
# Product Category:  Paracetamol
# Product Weight:  500mg
# Product Price:  10
# Product Manufacturing Date:  22-06-2021
# Product Expiery Date:  22-12-2021
# Product Quantity In Inventory:  1000
# ******************************
#
# 105 Product ID:
# Product Name:  Paracip Tablets
# Product Category:  Paracetamol
# Product Weight:  500mg
# Product Price:  11
# Product Manufacturing Date:  22-06-2021
# Product Expiery Date:  22-12-2021
# Product Quantity In Inventory:  6000
# ******************************
#
# 106 Product ID:
# Product Name:  Doliza Tablets
# Product Category:  Paracetamol
# Product Weight:  500mg
# Product Price:  11
# Product Manufacturing Date:  22-06-2021
# Product Expiery Date:  22-12-2021
# Product Quantity In Inventory:  3000
# ******************************
#
# 107 Product ID:
# Product Name:  Cipflam Tablets
# Product Category:  Paracetamol
# Product Weight:  500mg
# Product Price:  12
# Product Manufacturing Date:  22-06-2021
# Product Expiery Date:  22-12-2021
# Product Quantity In Inventory:  1500
# ******************************
#
# 108 Product ID:
# Product Name:  Fepanil Tablets
# Product Category:  Paracetamol
# Product Weight:  500mg
# Product Price:  13
# Product Manufacturing Date:  22-06-2021
# Product Expiery Date:  22-12-2021
# Product Quantity In Inventory:  2000
# ******************************
#
# 109 Product ID:
# Product Name:  Dolo Tablets
# Product Category:  Paracetamol
# Product Weight:  500mg
# Product Price:  14
# Product Manufacturing Date:  22-06-2021
# Product Expiery Date:  22-12-2021
# Product Quantity In Inventory:  1800
# ******************************
#
# 110 Product ID:
# Product Name:  Pacimol Tablets
# Product Category:  Paracetamol
# Product Weight:  500mg
# Product Price:  15
# Product Manufacturing Date:  22-06-2021
# Product Expiery Date:  22-12-2021
# Product Quantity In Inventory:  1000
# ******************************
#
# 111 Product ID:
# Product Name:  Crocin Advance Tablets
# Product Category:  Paracetamol
# Product Weight:  500mg
# Product Price:  16
# Product Manufacturing Date:  22-06-2021
# Product Expiery Date:  22-12-2021
# Product Quantity In Inventory:  2800
# ******************************
#
# 112 Product ID:
# Product Name:  Calpol Tablets
# Product Category:  Paracetamol
# Product Weight:  500mg
# Product Price:  17
# Product Manufacturing Date:  22-06-2021
# Product Expiery Date:  22-12-2021
# Product Quantity In Inventory:  2600
# ******************************
#
# 113 Product ID:
# Product Name:  Pacimol XP Tablets
# Product Category:  Paracetamol
# Product Weight:  500mg
# Product Price:  18
# Product Manufacturing Date:  22-06-2021
# Product Expiery Date:  22-12-2021
# Product Quantity In Inventory:  1100
# ******************************
#
# 114 Product ID:
# Product Name:  C 37 Tablets
# Product Category:  Paracetamol
# Product Weight:  500mg
# Product Price:  23
# Product Manufacturing Date:  22-06-2021
# Product Expiery Date:  22-12-2021
# Product Quantity In Inventory:  1200
# ******************************
#
# 115 Product ID:
# Product Name:  Crocin Tablets
# Product Category:  Paracetamol
# Product Weight:  500mg
# Product Price:  30
# Product Manufacturing Date:  22-06-2021
# Product Expiery Date:  22-12-2021
# Product Quantity In Inventory:  3800
# ******************************
#
# 116 Product ID:
# Product Name:  Actiflu Tablets
# Product Category:  Paracetamol
# Product Weight:  500mg
# Product Price:  38
# Product Manufacturing Date:  22-06-2021
# Product Expiery Date:  22-12-2021
# Product Quantity In Inventory:  1000
# ******************************
#
# 117 Product ID:
# Product Name:  Perfalgan Tablets
# Product Category:  Paracetamol
# Product Weight:  500mg
# Product Price:  165
# Product Manufacturing Date:  22-06-2021
# Product Expiery Date:  22-12-2021
# Product Quantity In Inventory:  1500
# ******************************
#
# 118 Product ID:
# Product Name:  Amoxicillin Tablets
# Product Category:  Cough & Cold
# Product Weight:  300mg
# Product Price:  10
# Product Manufacturing Date:  22-06-2021
# Product Expiery Date:  22-12-2021
# Product Quantity In Inventory:  1800
# ******************************
#
# 119 Product ID:
# Product Name:  Doxycycline Tablets
# Product Category:  Cough & Cold
# Product Weight:  500mg
# Product Price:  13
# Product Manufacturing Date:  22-06-2021
# Product Expiery Date:  22-12-2021
# Product Quantity In Inventory:  4000
# ******************************
#
# 120 Product ID:
# Product Name:  Cephalexin Tablets
# Product Category:  Cough & Cold
# Product Weight:  50mg
# Product Price:  12
# Product Manufacturing Date:  22-06-2021
# Product Expiery Date:  22-12-2021
# Product Quantity In Inventory:  5000
# ******************************
#
# 121 Product ID:
# Product Name:  Ciprofloacin Tablets
# Product Category:  Cough & Cold
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-9036430e60f7> in <module>
#      12   print("Product Name: " , record[products]['product name'])
#      13   print("Product Category: " ,record[products]['product category'])
# ---> 14   print("Product Weight: " ,record[products]['Power'])
#      15   print("Product Price: " ,record[products]['Price'])
#      16   print("Product Manufacturing Date: " ,record[products]['MFG Date'])
#
# KeyError: 'Power'

# %%
user_product = input("Enter the product id of the product you want to buy: ")

quantity_inv = record[user_product]['Quantity']
print("Maximum Quantity Available is: ", quantity_inv)
user_quantity = int(input("Enter the product quantity required: "))

quantity_check = True
while (quantity_check == True):
  if (user_quantity > quantity_inv): 
    print("Sorry, we don't have these many quantity of this product  in our inventory")
    print("You can purchase it to maximum " , quantity_inv ," quantity.")
    response = input("Do you still want to purchase this item?")
    if (response == "YES" or response == "yes" or response == "Yes"):
      user_quantity = int(input("Enter the product quantity required: "))
      for products in record:
            if(products == user_product):
              print("\n******************************")
              print("Product Name: " , record[products]['product name'])
              print("Product Category: " ,record[products]['product category'])
              print("Product Weight: " ,record[products]['Power'])
              print("Product Price: " ,record[products]['Price'])
              print("Product Manufacturing Date: " ,record[products]['MFG Date'])
              print("Product Expiery Date: " ,record[products]['Expirey Date'])
              print("Product Quantity: " , user_quantity)
              bill_amount = user_quantity * record[products]['Price']
              print("******************************\n")
              quantity_check = False

              referal_code = input("Have Any Referal Code? YES/NO ")
              if (referal_code == "YES" or referal_code == "Yes" or referal_code == "yes"):
                while(referal_code == "yes" or referal_code == "YES" or referal_code == "Yes" ):
                  referal_code2 = input("Enter your referal code: ".title())
                  if (referal_code2 == "LESS500"):
                    if (bill_amount >= 1000):
                      print("Coupon has been successfully applied.")
                      print("******************************")
                      bill_amount = bill_amount - 500
                      referal_code = "NO"
                    else:
                      print("Cannot apply this coupon as your bill amount is ", 1000- bill_amount, " less." )
                      print("******************************")
                      referal_code = "NO"
                  elif (referal_code2 == "LESS50"):
                    if (bill_amount >= 500):
                      print("Coupon has been successfully applied.")
                      print("******************************")
                      bill_amount = bill_amount - 50
                      referal_code = "NO"
                    else:
                      print("Cannot apply this coupon as your bill amount is ", 500 - bill_amount, " less." )
                      print("******************************")
                      referal_code = "NO"
                  else:
                    print("This is not a valid referal code")
                    referal_code = input("Do you have any another referal code? YES/NO")

    else:
        response2 = input("Do you want another product?") 
        if (response2 == "YES" or response2 == "yes" or response2 == "Yes"):
          user_product = str(input("Enter the product id of the product you want to buy: "))
          user_quantity = int(input("Enter the product quantity required: "))
          if (user_quantity < quantity_inv):
            for products in record:
              if (products == user_product):
                print("\n******************************")
                print("Product Name: " , record[products]['product name'])
                print("Product Category: " ,record[products]['product category'])
                print("Product Weight: " ,record[products]['Power'])
                print("Product Price: " ,record[products]['Price'])
                print("Product Manufacturing Date: " ,record[products]['MFG Date'])
                print("Product Expiery Date: " ,record[products]['Expirey Date'])
                print("Product Quantity: " , user_quantity)
                bill_amount = user_quantity * record[products]['Price']
                print("******************************\n")
                quantity_check = False

                referal_code = input("Have Any Referal Code? YES/NO ")
                if (referal_code == "YES" or referal_code == "Yes" or referal_code == "yes"):
                  while(referal_code == "yes" or referal_code == "YES" or referal_code == "Yes" ):
                    referal_code2 = input("Enter your referal code: ".title())
                    if (referal_code2 == "LESS500"):
                      if (bill_amount >= 1000):
                        print("Coupon has been successfully applied.")
                        print("******************************")
                        bill_amount = bill_amount - 500
                        referal_code = "NO"
                      else:
                        print("Cannot apply this coupon as your bill amount is ", 1000- bill_amount, " less." )
                        print("******************************")
                        referal_code = "NO"
                    elif (referal_code2 == "LESS50"):
                      if (bill_amount >= 500):
                        print("Coupon has been successfully applied.")
                        print("******************************")
                        bill_amount = bill_amount - 50
                        referal_code = "NO"
                      else:
                        print("Cannot apply this coupon as your bill amount is ", 500 - bill_amount, " less." )
                        print("******************************")
                        referal_code = "NO"
                    else:
                      print("This is not a valid referal code")
                      referal_code = input("Do you have any another referal code? YES/NO")
          else:
                quantity_check = True
        else:
          print("Sorry for your inconvinence.")
          print("Hope to see you again! we will not disappointed you next time.")
          quantity_check = False
          bill_amount = 0


  else:
    for products in record:
      if(products == user_product):
        print("\n******************************")
        print("Product Name: " , record[products]['product name'])
        print("Product Category: " ,record[products]['product category'])
        print("Product Weight: " ,record[products]['Power'])
        print("Product Price: " ,record[products]['Price'])
        print("Product Manufacturing Date: " ,record[products]['MFG Date'])
        print("Product Expiery Date: " ,record[products]['Expirey Date'])
        print("Product Quantity: " , user_quantity)
        bill_amount = user_quantity * record[products]['Price']
        print("******************************\n")
        quantity_check = False

        referal_code = input("Have Any Referal Code? YES/NO ")
        if (referal_code == "YES" or referal_code == "Yes" or referal_code == "yes"):
          while(referal_code == "yes" or referal_code == "YES" or referal_code == "Yes" ):
            referal_code2 = input("Enter your referal code: ".title())
            if (referal_code2 == "LESS500"):
              if (bill_amount >= 1000):
                print("Coupon has been successfully applied.")
                print("******************************")
                bill_amount = bill_amount - 500
                referal_code = "NO"
              else:
                print("Cannot apply this coupon as your bill amount is ", 1000- bill_amount, " less." )
                print("******************************")
                referal_code = "NO"
            elif (referal_code2 == "LESS50"):
              if (bill_amount >= 500):
                print("Coupon has been successfully applied.")
                print("******************************")
                bill_amount = bill_amount - 50
                referal_code = "NO"
              else:
                print("Cannot apply this coupon as your bill amount is ", 500 - bill_amount, " less." )
                print("******************************")
                referal_code = "NO"
            else:
              print("This is not a valid referal code")
              referal_code = input("Do you have any another referal code? YES/NO")
        
print("\n******************************")
print("Customer Name: " + name)
print("Customer Contact Number: " , Contact_Number)
print("Total Billing Amount: Rs " , bill_amount)
print("Thanks for visiting")
print("******************************")
# Out:
# Enter the product id of the product you want to buy: 101
# Maximum Quantity Available is:  1000
# Enter the product quantity required: 10
#
# ******************************
# Product Name:  Algina Tablets
# Product Category:  Paracetamol
# Product Weight:  500mg
# Product Price:  7.0
# Product Manufacturing Date:  22-06-2021
# Product Expiery Date:  22-12-2021
# Product Quantity:  10
# ******************************
#
# Have Any Referal Code? YES/NO yes
# Enter Your Referal Code: LESS50
# Cannot apply this coupon as your bill amount is  430.0  less.
# ******************************
#
# ******************************
# Customer Name: khushi
# Customer Contact Number:  2882772829
# Total Billing Amount: Rs  70.0
# Thanks for visiting
# ******************************

# %%
# updation of the inventory
fd = open("record.json",'r')
txt = fd.read()
fd.close()

for products in record:
  if(products == user_product):
    record[products]['Quantity'] = record[products]['Quantity'] - user_quantity

# %%
record
# Out:
# {'101': {'product name': 'Algina Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 7.0,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 990},
#  '102': {'product name': 'Cipmol Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 9,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 4000},
#  '103': {'product name': 'Malidens Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 10,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 3000},
#  '104': {'product name': 'Parafast Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 10,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 1000},
#  '105': {'product name': 'Paracip Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 11,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 6000},
#  '106': {'product name': 'Doliza Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 11,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 3000},
#  '107': {'product name': 'Cipflam Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 12,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 1500},
#  '108': {'product name': 'Fepanil Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 13,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 2000},
#  '109': {'product name': 'Dolo Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 14,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 1800},
#  '110': {'product name': 'Pacimol Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 15,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 1000},
#  '111': {'product name': 'Crocin Advance Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 16,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 2800},
#  '112': {'product name': 'Calpol Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 17,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 2600},
#  '113': {'product name': 'Pacimol XP Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 18,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 1100},
#  '114': {'product name': 'C 37 Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 23,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 1200},
#  '115': {'product name': 'Crocin Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 30,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 3800},
#  '116': {'product name': 'Actiflu Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 38,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 1000},
#  '117': {'product name': 'Perfalgan Tablets',
#   'product category': 'Paracetamol',
#   'MFG Date': '22-06-2021',
#   'Price': 165,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 1500},
#  '118': {'product name': 'Amoxicillin Tablets',
#   'product category': 'Cough & Cold',
#   'MFG Date': '22-06-2021',
#   'Price': 10,
#   'Expirey Date': '22-12-2021',
#   'Power': '300mg',
#   'Quantity': 1800},
#  '119': {'product name': 'Doxycycline Tablets',
#   'product category': 'Cough & Cold',
#   'MFG Date': '22-06-2021',
#   'Price': 13,
#   'Expirey Date': '22-12-2021',
#   'Power': '500mg',
#   'Quantity': 4000},
#  '120': {'product name': 'Cephalexin Tablets',
#   'product category': 'Cough & Cold',
#   'MFG Date': '22-06-2021',
#   'Price': 12,
#   'Expirey Date': '22-12-2021',
#   'Power': '50mg',
#   'Quantity': 5000},
#  '121': {'product name': 'Ciprofloacin Tablets',
#   'product category': 'Cough & Cold',
#   'MFG Date': '22-06-2021',
#   'Price': 10,
#   'Expirey Date': '22-12-2021',
#   'Weight': '100mg',
#   'Quantity': 1000},
#  '122': {'product name': 'ClindamycinTablets',
#   'product category': 'Cough & Cold',
#   'MFG Date': '22-06-2021',
#   'Price': 13,
#   'Expirey Date': '22-12-2021',
#   'Weight': '500mg',
#   'Quantity': 5000},
#  '123': {'product name': 'Metronidazole Tablets',
#   'product category': 'Cough & Cold',
#   'MFG Date': '22-06-2021',
#   'Price': 19,
#   'Expirey Date': '22-12-2021',
#   'Weight': '50mg',
#   'Quantity': 3000},
#  '124': {'product name': 'Azithromycin Tablets',
#   'product category': 'Cough & Cold',
#   'MFG Date': '22-06-2021',
#   'Price': 100,
#   'Expirey Date': '22-12-2021',
#   'Weight': '500mg',
#   'Quantity': 2000},
#  '125': {'product name': 'Gluconorm-G Tablets',
#   'product category': 'Diabetes',
#   'MFG Date': '22-06-2021',
#   'Price': 30,
#   'Expirey Date': '22-12-2021',
#   'Weight': '200mg',
#   'Quantity': 2000},
#  '126': {'product name': 'Novomix Tablets',
#   'product category': 'Diabetes',
#   'MFG Date': '22-06-2021',
#   'Price': 20,
#   'Expirey Date': '22-12-2021',
#   'Weight': '500mg',
#   'Quantity': 2000},
#  '127': {'product name': 'Mixtard Tablets',
#   'product category': 'Diabetes',
#   'MFG Date': '22-06-2021',
#   'Price': 50,
#   'Expirey Date': '22-12-2021',
#   'Weight': '500mg',
#   'Quantity': 2000},
#  '128': {'product name': 'Lantus Tablets',
#   'product category': 'Diabetes',
#   'MFG Date': '22-06-2021',
#   'Price': 130,
#   'Expirey Date': '22-12-2021',
#   'Weight': '500mg',
#   'Quantity': 2000},
#  '129': {'product name': 'Thyroid Desiccated Tablets',
#   'product category': 'Thyroid',
#   'MFG Date': '22-06-2021',
#   'Price': 110,
#   'Expirey Date': '22-12-2021',
#   'Weight': '500mg',
#   'Quantity': 1000},
#  '130': {'product name': 'Levothyroxine Tablets',
#   'product category': 'Thyroid',
#   'MFG Date': '22-06-2021',
#   'Price': 200,
#   'Expirey Date': '22-12-2021',
#   'Weight': '500mg',
#   'Quantity': 1000},
#  '131': {'product name': 'Liotrix Tablets',
#   'product category': 'Thyroid',
#   'MFG Date': '22-06-2021',
#   'Price': 100,
#   'Expirey Date': '22-12-2021',
#   'Weight': '500mg',
#   'Quantity': 1000}}
